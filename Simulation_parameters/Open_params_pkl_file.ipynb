# %%
import pickle
import pandas as pd
import sys
from pathlib import Path

NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent  # Mapping_Recurrent_Inhibition/
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
# Import from other files in the project
from simulator import (
    SimulationParameters,
    run_simulation,
)
from analyzer import (
    AnalyzesParams,
    analyze_data,
)

retrieve_pkl_path = f"{str(PROJECT_ROOT)}\\Simulation_parameters\\FIG_2_Cross_hist_metrics\\Simulation_peak_height_highfreq_input_amplitude_correl_batch0.pkl" # Replace with simulation batch to open
with open(retrieve_pkl_path, "rb") as f:
    pickle_file = pickle.load(f)

# %%
pickle_file.keys() # display the keys

# %%
print(f"Number of simulations = {len(pickle_file['params_prior_list'])}")

# %%
selected_simulation_idx_to_check = 0 # choose any integer < len(pickle_file['params_prior_list'])
print(f"{pickle_file['params_prior_list'][0]}")
